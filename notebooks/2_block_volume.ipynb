# %%
netID = "ahmed@offsechq.com"

# %%
# run in Chameleon Jupyter environment
from chi import server, context
import chi, os, time, datetime

# %%
# ahmed_offsechq_com

# %%
username
# Out:
# 'ahmed_offsechq_com'

# %%
cinder_client = chi.clients.cinder()

# %%
cinder_client.volumes.list()
# Out:
# ---------------------------------------------------------------------------
# EndpointNotFound                          Traceback (most recent call last)
# /tmp/ipykernel_232/1346209221.py in <cell line: 1>()
# ----> 1 cinder_client.volumes.list()
#
# /opt/conda/lib/python3.10/site-packages/cinderclient/v3/volumes_base.py in list(self, detailed, search_opts, marker, limit, sort)
#     220                                    search_opts=search_opts, marker=marker,
#     221                                    limit=limit, sort=sort)
# --> 222         return self._list(url, resource_type, limit=limit)
#     223
#     224     def delete(self, volume, cascade=False):
#
# /opt/conda/lib/python3.10/site-packages/cinderclient/base.py in _list(self, url, response_key, obj_class, body, limit, items)
#      76             resp, body = self.api.client.post(url, body=body)
#      77         else:
# ---> 78             resp, body = self.api.client.get(url)
#      79
#      80         if obj_class is None:
#
# /opt/conda/lib/python3.10/site-packages/cinderclient/client.py in get(self, url, **kwargs)
#     218
#     219     def get(self, url, **kwargs):
# --> 220         return self._cs_request(url, 'GET', **kwargs)
#     221
#     222     def post(self, url, **kwargs):
#
# /opt/conda/lib/python3.10/site-packages/cinderclient/client.py in _cs_request(self, url, method, **kwargs)
#     209             attempts += 1
#     210             try:
# --> 211                 return self.request(url, method, **kwargs)
#     212             except exceptions.OverLimit as overlim:
#     213                 if attempts > self.retries or overlim.retry_after < 1:
#
# /opt/conda/lib/python3.10/site-packages/cinderclient/client.py in request(self, *args, **kwargs)
#     190         # keystoneauth, here we need to raise the cinderclient errors.
#     191         raise_exc = kwargs.pop('raise_exc', True)
# --> 192         resp, body = super(SessionClient, self).request(*args,
#     193                                                         raise_exc=False,
#     194                                                         **kwargs)
#
# /opt/conda/lib/python3.10/site-packages/keystoneauth1/adapter.py in request(self, url, method, **kwargs)
#     657             pass
#     658
# --> 659         resp = self._request(url, method, **kwargs)
#     660
#     661         try:
#
# /opt/conda/lib/python3.10/site-packages/keystoneauth1/adapter.py in _request(self, url, method, **kwargs)
#     292             kwargs.setdefault('raise_exc', self.raise_exc)
#     293
# --> 294         return self.session.request(url, method, **kwargs)
#     295
#     296     def get_token(
#
# /opt/conda/lib/python3.10/site-packages/keystoneauth1/adapter.py in request(self, url, method, **kwargs)
#     592         self, url: str, method: str, **kwargs: ty.Any
#     593     ) -> requests.Response:
# --> 594         return self._request(url, method, **kwargs)
#     595
#     596     def get(self, url: str, **kwargs: ty.Any) -> requests.Response:
#
# /opt/conda/lib/python3.10/site-packages/keystoneauth1/adapter.py in _request(self, url, method, **kwargs)
#     292             kwargs.setdefault('raise_exc', self.raise_exc)
#     293
# --> 294         return self.session.request(url, method, **kwargs)
#     295
#     296     def get_token(
#
# /opt/conda/lib/python3.10/site-packages/keystoneauth1/session.py in request(self, url, method, json, original_ip, user_agent, redirect, authenticated, endpoint_filter, auth, requests_auth, raise_exc, allow_reauth, log, endpoint_override, connect_retries, logger, allow, client_name, client_version, microversion, microversion_service_type, status_code_retries, retriable_status_codes, rate_semaphore, global_request_id, connect_retry_delay, status_code_retry_delay, **kwargs)
#     920                 base_url = endpoint_override % _StringFormatter(self, auth)
#     921             elif endpoint_filter:
# --> 922                 base_url = self.get_endpoint(
#     923                     auth, allow=allow, **endpoint_filter
#     924                 )
#
# /opt/conda/lib/python3.10/site-packages/keystoneauth1/session.py in get_endpoint(self, auth, endpoint_override, **kwargs)
#    1435         auth = self._auth_required(auth, 'determine endpoint URL')
#    1436
# -> 1437         return auth.get_endpoint(self, **kwargs)
#    1438
#    1439     def get_endpoint_data(
#
# /opt/conda/lib/python3.10/site-packages/keystoneauth1/identity/base.py in get_endpoint(self, session, service_type, interface, region_name, service_name, version, allow, allow_version_hack, skip_discovery, min_version, max_version, **kwargs)
#     413         # will still run discovery if the version requested is not the
#     414         # version in the catalog.
# --> 415         endpoint_data = self.get_endpoint_data(
#     416             session,
#     417             service_type=service_type,
#
# /opt/conda/lib/python3.10/site-packages/keystoneauth1/identity/base.py in get_endpoint_data(self, session, endpoint_override, discover_versions, service_type, interface, region_name, service_name, allow, allow_version_hack, skip_discovery, min_version, max_version, **kwargs)
#     298             # NOTE(mordred): service_catalog.url_data_for raises if it can't
#     299             # find a match, so this will always be a valid object.
# --> 300             endpoint_data = service_catalog.endpoint_data_for(
#     301                 service_type=service_type,
#     302                 interface=interface,
#
# /opt/conda/lib/python3.10/site-packages/keystoneauth1/access/service_catalog.py in endpoint_data_for(self, service_type, interface, region_name, service_name, service_id, endpoint_id)
#     540             msg = f'{interface} endpoint for {service_type} service not found'
#     541
# --> 542         raise exceptions.EndpointNotFound(msg)
#     543
#     544
#
# EndpointNotFound: publicURL endpoint for volumev3 service in CHI@UC region not found

# %%
volume = cinder_client.volumes.create(name=f"block-persist-python-{username}", size=2)
volume._info
server_id = chi.server.get_server(f"node-persist-{username}").id
volume_manager = chi.nova().volumes
volume_manager.create_server_volume(server_id = s.id, volume_id = volume.id)
volume_manager.delete_server_volume(server_id = s.id, volume_id = volume.id)
cinder_client.volumes.delete(volume = volume)
# Out:
# ---------------------------------------------------------------------------
# EndpointNotFound                          Traceback (most recent call last)
# /tmp/ipykernel_232/580801799.py in <cell line: 1>()
# ----> 1 volume = cinder_client.volumes.create(name=f"block-persist-python-{username}", size=2)
#       2 volume._info
#
# /opt/conda/lib/python3.10/site-packages/cinderclient/v3/volumes.py in create(self, size, consistencygroup_id, group_id, snapshot_id, source_volid, name, description, volume_type, user_id, project_id, availability_zone, metadata, imageRef, scheduler_hints, backup_id)
#     131             body['OS-SCH-HNT:scheduler_hints'] = scheduler_hints
#     132
# --> 133         return self._create('/volumes', body, 'volume')
#     134
#     135     @api_versions.wraps('3.40')
#
# /opt/conda/lib/python3.10/site-packages/cinderclient/base.py in _create(self, url, body, response_key, return_raw, **kwargs)
#     304     def _create(self, url, body, response_key, return_raw=False, **kwargs):
#     305         self.run_hooks('modify_body_for_create', body, **kwargs)
# --> 306         resp, body = self.api.client.post(url, body=body)
#     307         if return_raw:
#     308             return common_base.DictWithMeta(body[response_key], resp)
#
# /opt/conda/lib/python3.10/site-packages/cinderclient/client.py in post(self, url, **kwargs)
#     221
#     222     def post(self, url, **kwargs):
# --> 223         return self._cs_request(url, 'POST', **kwargs)
#     224
#     225     def put(self, url, **kwargs):
#
# /opt/conda/lib/python3.10/site-packages/cinderclient/client.py in _cs_request(self, url, method, **kwargs)
#     209             attempts += 1
#     210             try:
# --> 211                 return self.request(url, method, **kwargs)
#     212             except exceptions.OverLimit as overlim:
#     213                 if attempts > self.retries or overlim.retry_after < 1:
#
# /opt/conda/lib/python3.10/site-packages/cinderclient/client.py in request(self, *args, **kwargs)
#     190         # keystoneauth, here we need to raise the cinderclient errors.
#     191         raise_exc = kwargs.pop('raise_exc', True)
# --> 192         resp, body = super(SessionClient, self).request(*args,
#     193                                                         raise_exc=False,
#     194                                                         **kwargs)
#
# /opt/conda/lib/python3.10/site-packages/keystoneauth1/adapter.py in request(self, url, method, **kwargs)
#     657             pass
#     658
# --> 659         resp = self._request(url, method, **kwargs)
#     660
#     661         try:
#
# /opt/conda/lib/python3.10/site-packages/keystoneauth1/adapter.py in _request(self, url, method, **kwargs)
#     292             kwargs.setdefault('raise_exc', self.raise_exc)
#     293
# --> 294         return self.session.request(url, method, **kwargs)
#     295
#     296     def get_token(
#
# /opt/conda/lib/python3.10/site-packages/keystoneauth1/adapter.py in request(self, url, method, **kwargs)
#     592         self, url: str, method: str, **kwargs: ty.Any
#     593     ) -> requests.Response:
# --> 594         return self._request(url, method, **kwargs)
#     595
#     596     def get(self, url: str, **kwargs: ty.Any) -> requests.Response:
#
# /opt/conda/lib/python3.10/site-packages/keystoneauth1/adapter.py in _request(self, url, method, **kwargs)
#     292             kwargs.setdefault('raise_exc', self.raise_exc)
#     293
# --> 294         return self.session.request(url, method, **kwargs)
#     295
#     296     def get_token(
#
# /opt/conda/lib/python3.10/site-packages/keystoneauth1/session.py in request(self, url, method, json, original_ip, user_agent, redirect, authenticated, endpoint_filter, auth, requests_auth, raise_exc, allow_reauth, log, endpoint_override, connect_retries, logger, allow, client_name, client_version, microversion, microversion_service_type, status_code_retries, retriable_status_codes, rate_semaphore, global_request_id, connect_retry_delay, status_code_retry_delay, **kwargs)
#     920                 base_url = endpoint_override % _StringFormatter(self, auth)
#     921             elif endpoint_filter:
# --> 922                 base_url = self.get_endpoint(
#     923                     auth, allow=allow, **endpoint_filter
#     924                 )
#
# /opt/conda/lib/python3.10/site-packages/keystoneauth1/session.py in get_endpoint(self, auth, endpoint_override, **kwargs)
#    1435         auth = self._auth_required(auth, 'determine endpoint URL')
#    1436
# -> 1437         return auth.get_endpoint(self, **kwargs)
#    1438
#    1439     def get_endpoint_data(
#
# /opt/conda/lib/python3.10/site-packages/keystoneauth1/identity/base.py in get_endpoint(self, session, service_type, interface, region_name, service_name, version, allow, allow_version_hack, skip_discovery, min_version, max_version, **kwargs)
#     413         # will still run discovery if the version requested is not the
#     414         # version in the catalog.
# --> 415         endpoint_data = self.get_endpoint_data(
#     416             session,
#     417             service_type=service_type,
#
# /opt/conda/lib/python3.10/site-packages/keystoneauth1/identity/base.py in get_endpoint_data(self, session, endpoint_override, discover_versions, service_type, interface, region_name, service_name, allow, allow_version_hack, skip_discovery, min_version, max_version, **kwargs)
#     298             # NOTE(mordred): service_catalog.url_data_for raises if it can't
#     299             # find a match, so this will always be a valid object.
# --> 300             endpoint_data = service_catalog.endpoint_data_for(
#     301                 service_type=service_type,
#     302                 interface=interface,
#
# /opt/conda/lib/python3.10/site-packages/keystoneauth1/access/service_catalog.py in endpoint_data_for(self, service_type, interface, region_name, service_name, service_id, endpoint_id)
#     540             msg = f'{interface} endpoint for {service_type} service not found'
#     541
# --> 542         raise exceptions.EndpointNotFound(msg)
#     543
#     544
#
# EndpointNotFound: publicURL endpoint for volumev3 service in CHI@UC region not found

# %%
# run in Chameleon Jupyter environment
username = os.getenv('USER') 
s = server.get_server(f"node-persist-{username}")
# Out:
# ---------------------------------------------------------------------------
# NotFound                                  Traceback (most recent call last)
# /tmp/ipykernel_232/2271401876.py in <cell line: 3>()
#       1 # run in Chameleon Jupyter environment
#       2 username = os.getenv('USER') # all exp resources will have this prefix
# ----> 3 s = server.get_server(f"node-persist-{username}")
#
# /opt/conda/lib/python3.10/site-packages/chi/server.py in get_server(name)
#     840     """
#     841     if Version(context.version) >= Version("1.0"):
# --> 842         nova_server = nova().servers.get(get_server_id(name))
#     843         return Server._from_nova_server(nova_server)
#     844     try:
#
# /opt/conda/lib/python3.10/site-packages/novaclient/v2/servers.py in get(self, server)
#     975         :rtype: :class:`Server`
#     976         """
# --> 977         return self._get("/servers/%s" % base.getid(server), "server")
#     978
#     979     def list(self, detailed=True, search_opts=None, marker=None, limit=None,
#
# /opt/conda/lib/python3.10/site-packages/novaclient/base.py in _get(self, url, response_key, filters)
#     350         if filters:
#     351             url = utils.get_url_with_filter(url, filters)
# --> 352         resp, body = self.api.client.get(url)
#     353         if response_key is not None:
#     354             content = body[response_key]
#
# /opt/conda/lib/python3.10/site-packages/keystoneauth1/adapter.py in get(self, url, **kwargs)
#     673         This calls :py:meth:`.request()` with ``method`` set to ``GET``.
#     674         """
# --> 675         return self.request(url, 'GET', **kwargs)
#     676
#     677     def head(
#
# /opt/conda/lib/python3.10/site-packages/novaclient/client.py in request(self, url, method, **kwargs)
#      76         # api_versions.check_headers(resp, self.api_version)
#      77         if raise_exc and resp.status_code >= 400:
# ---> 78             raise exceptions.from_response(resp, body, url, method)
#      79
#      80         return resp, body
#
# NotFound: Instance None could not be found. (HTTP 404) (Request-ID: req-d7bb2563-1cd0-4085-84ec-02bd1b8b68ca)

# %%
s
